# %%
import trimesh
import networkx

# %%
world = trimesh.load("Town05(partial).stl")

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.plot_trisurf(world.vertices[:, 0], world.vertices[:,1], world.vertices[:,2], triangles=world.faces);

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(projection='3d')


ax.plot_trisurf(world["vertices"][:, 0], world["vertices"][:,1], world["vertices"][:,2], triangles=world["faces"]);

# %%
meshes = world.split()

# %%
len(meshes)
# Out:
# 8981

# %%
import matplotlib.pyplot as plt

mesh = meshes[263]

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.plot_trisurf(mesh.vertices[:, 0], mesh.vertices[:,1], mesh.vertices[:,2], triangles=mesh.faces);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_39704\973918067.py in <module>
#       1 import matplotlib.pyplot as plt
#       2
# ----> 3 mesh = meshes[263]
#       4
#       5 fig = plt.figure()
#
# NameError: name 'meshes' is not defined
